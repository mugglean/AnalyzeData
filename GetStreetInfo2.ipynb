# %%
import pandas as pd
import numpy as np

# %%
street_table_info1=pd.read_csv("F:\\BWMProject\\10.2\\locationdict_1_result.csv")
street_table_info1
# Out:
#       Latitude   Longitude                                        street_info
# 0     1.359951  103.884701    900 Upper Serangoon Rd, Kovan, Singapore 534799
# 1     1.363290  103.965668                   21 Loyang View, Singapore 507249
# 2     1.312430  103.923304                     55 Siglap Rd, Singapore 455871
# 3     1.300316  103.849838                    30 Selegie Rd, Singapore 188351
# 4     1.321748  103.863081                 947 Serangoon Rd, Singapore 328144
# 5     1.354087  103.867940   304 Serangoon Ave 2, Block 304, Singapore 550304
# 6     1.358067  103.950352  445 Tampines Street 42, Block 445, Singapore 5...
# 7     1.306273  103.826466            19 Tanglin Rd, #B1-19, Singapore 247909
# 8     1.306302  103.828054                   21 Cuscaden Rd, Singapore 249720
# 9     1.320701  103.951752                        48 Kew Dr, Singapore 467973
# 10    1.374031  103.951695                   120 Pasir Ris Central, Singapore
# ...

# %%
street_table_info2=pd.read_csv("F:\\BWMProject\\10.2\\locationdict_2_result.csv")
street_table_info2
# Out:
#       Latitude   Longitude                                        street_info
# 0     1.282686  103.830435    78 Moh Guan Terrace, Block 78, Singapore 162078
# 1     1.352625  103.944805             4 Tampines Central 5, Singapore 529510
# 2     1.300717  103.840279                   181 Orchard Rd, Singapore 238896
# 3     1.330471  103.852859           297 Lorong 6 Toa Payoh, Singapore 319389
# 4     1.286351  103.850003                    32c Boat Quay, Singapore 049821
# 5     1.352544  103.944069  B1, 2 Tampines Central 5, 12a Century Square, ...
# 6     1.374168  103.958205  477 Pasir Ris Drive 6, Block 477, Singapore 51...
# 7     1.315190  103.764532          3155 Commonwealth Ave W, Singapore 129588
# 8     1.302079  103.849758                      8 Wilkie Rd, Singapore 228095
# 9     1.320467  103.862708             34 Whampoa W, #01-55, Singapore 330034
# 10    1.286466  103.826990  300 Tiong Bahru Rd, Tiong Bahru MRT Station, S...
# ...

# %%
Final_rs=pd.concat([street_table_info1,street_table_info2],ignore_index=True)
Final_rs
# Out:
#       Latitude   Longitude                                        street_info
# 0     1.359951  103.884701    900 Upper Serangoon Rd, Kovan, Singapore 534799
# 1     1.363290  103.965668                   21 Loyang View, Singapore 507249
# 2     1.312430  103.923304                     55 Siglap Rd, Singapore 455871
# 3     1.300316  103.849838                    30 Selegie Rd, Singapore 188351
# 4     1.321748  103.863081                 947 Serangoon Rd, Singapore 328144
# 5     1.354087  103.867940   304 Serangoon Ave 2, Block 304, Singapore 550304
# 6     1.358067  103.950352  445 Tampines Street 42, Block 445, Singapore 5...
# 7     1.306273  103.826466            19 Tanglin Rd, #B1-19, Singapore 247909
# 8     1.306302  103.828054                   21 Cuscaden Rd, Singapore 249720
# 9     1.320701  103.951752                        48 Kew Dr, Singapore 467973
# 10    1.374031  103.951695                   120 Pasir Ris Central, Singapore
# ...

# %%
for i in range(3,11):
    street_info_table=pd.read_csv("F:\\BWMProject\\10.2\\locationdict_"+str(i)+"_result.csv")
    Final_rs=pd.concat([Final_rs,street_info_table],ignore_index=True)
Final_rs
# Out:
#        Latitude   Longitude                                        street_info
# 0      1.359951  103.884701    900 Upper Serangoon Rd, Kovan, Singapore 534799
# 1      1.363290  103.965668                   21 Loyang View, Singapore 507249
# 2      1.312430  103.923304                     55 Siglap Rd, Singapore 455871
# 3      1.300316  103.849838                    30 Selegie Rd, Singapore 188351
# 4      1.321748  103.863081                 947 Serangoon Rd, Singapore 328144
# 5      1.354087  103.867940   304 Serangoon Ave 2, Block 304, Singapore 550304
# 6      1.358067  103.950352  445 Tampines Street 42, Block 445, Singapore 5...
# 7      1.306273  103.826466            19 Tanglin Rd, #B1-19, Singapore 247909
# 8      1.306302  103.828054                   21 Cuscaden Rd, Singapore 249720
# 9      1.320701  103.951752                        48 Kew Dr, Singapore 467973
# 10     1.374031  103.951695                   120 Pasir Ris Central, Singapore
# ...

# %%
Final_rs.shape
# Out:
# (21070, 3)

# %%
Final_rs.to_csv("F:\\BWMProject\\10.2\\locationdict_dict_final.csv",index=False)
Final_rs.to_csv("F:\\BWMProject\\10.2\\locationdict_dict_final.txt",index=False,sep='\t')

# %% [markdown]
# 其中有一行多了空格，需要修改
# 修改之后得到总表
