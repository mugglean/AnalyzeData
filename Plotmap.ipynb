# %%
from gmplot import gmplot
import numpy as np
import pandas as pd

# %%
location_table=pd.read_csv("F:\\BWMProject\\10.2\\locationdict.csv")

# %%
location_table
# Out:
#        Latitude   Longitude
# 0      1.359951  103.884701
# 1      1.363290  103.965668
# 2      1.312430  103.923304
# 3      1.300316  103.849838
# 4      1.321748  103.863081
# 5      1.354087  103.867940
# 6      1.358067  103.950352
# 7      1.306273  103.826466
# 8      1.306302  103.828054
# 9      1.320701  103.951752
# 10     1.374031  103.951695
# 11     1.356170  103.987033
# 12     1.362477  103.887835
# 13     1.271363  103.819167
# 14     1.282654  103.846735
# 15     1.354713  103.989186
# 16     1.301734  103.784801
# 17     1.343084  103.852215
# 18     1.293597  103.812771
# 19     1.321666  103.932271
# 20     1.305366  103.854854
# 21     1.286880  103.808055
# 22     1.325207  103.930229
# 23     1.290570  103.845520
# 24     1.290786  103.845801
# 25     1.317213  103.978536
# 26     1.302261  103.793721
# 27     1.315276  103.762252
# 28     1.338183  103.844780
# 29     1.315501  103.817089
# ...         ...         ...
# 21040  1.284995  103.833767
# ...

# %%
location_table_sampe=location_table.sample(n=40)
location_table_sampe
# Out:
#        Latitude   Longitude
# 5177   1.371297  103.890509
# 11664  1.372961  103.896289
# 93     1.312060  103.876805
# 4066   1.303962  103.796935
# 1501   1.350610  103.872747
# 12019  1.354048  103.945223
# 4320   1.345852  103.953888
# 19243  1.291819  103.863353
# 15575  1.323842  103.867352
# 10802  1.284954  103.851608
# 6282   1.307817  103.856978
# 10679  1.282969  103.863636
# 8239   1.300706  103.913176
# 16434  1.320362  103.886875
# 2617   1.294088  103.853159
# 14282  1.289689  103.858167
# 19670  1.323130  103.934047
# 10550  1.304897  103.830160
# 16980  1.397050  103.908222
# 3131   1.301078  103.836902
# 2550   1.392342  103.916498
# 6930   1.323613  103.810382
# 13296  1.312733  103.925601
# 1152   1.332712  103.847987
# 2634   1.354000  103.945089
# 6541   1.300078  103.859576
# 9202   1.289755  103.845778
# 14826  1.307256  103.833053
# 10967  1.301412  103.849985
# 10537  1.278019  103.843159
# 1623   1.332045  103.678371
# 17654  1.289342  103.856946
# ...

# %%
gmap_end = gmplot.GoogleMapPlotter(1.335946,103.906772,13)
gmap_end.scatter(location_table['Latitude'], location_table['Longitude'], color='red', size=40, marker=False)
gmap_end.draw("poi.html")
